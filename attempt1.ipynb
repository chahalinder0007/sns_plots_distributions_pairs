# %%
from tensorflow.keras.datasets import boston_housing

# %%
data=boston_housing.load_data()
train,test=data

# %% [markdown]
# ---
# ---
# ---
# ---
#
# Go to this [link](https://seaborn.pydata.org/tutorial/distributions.html) to explore more great visualizations for distributions and kernals
#
# ---
# ---
# ---
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
train[1].shape
# Out:
# (404,)

# %%
plt.hist(train[1])
# Out:
# (array([ 15.,  48.,  72., 120.,  64.,  31.,  21.,   8.,   8.,  17.]),
#  array([ 5. ,  9.5, 14. , 18.5, 23. , 27.5, 32. , 36.5, 41. , 45.5, 50. ]),
#  <a list of 10 Patch objects>)

# %%
sns.distplot(train[1])

# %%
sns.pairplot(pd.DataFrame(train[0]))
